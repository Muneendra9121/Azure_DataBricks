# %%
# %sql
#create database maha

# %%
# %sql
use maha

# %%
# %sql
#create table rebaltb(id int,name varchar(20), salary int, dept char(20))

# %%
# %sql
insert into rebaltb values(1,'muni',100000,'it'),(2,'mk',1500000,'mm'),(3,'vasim',200000,'pp')

# %%
# %sql
select * from rebaltb

# %%
# %sql
select sum(salary) from rebaltb

# %%
# %sql
select * from rebaltb order by salary desc limit 2

# %%
# %sql

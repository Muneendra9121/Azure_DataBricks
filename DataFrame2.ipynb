# %%
data = [
    (1, 'Alice', 'HR', 60000),
    (2, 'Bob', 'IT', 75000),
    (3, 'Charlie', 'IT', 72000),
    (4, 'David', 'HR', 58000),
    (5, 'Eva', 'Finance', 80000),
    (1, 'Alice', 'HR', 60000),
    (2, 'Bob', 'IT', 75000),
    (3, 'Charlie', 'IT', 72000),
    (4, 'David', 'HR', 58000),
    (5, 'Eva', 'Finance', 80000)
]

columns = ['emp_id', 'name', 'department', 'salary']
df = spark.createDataFrame(data, schema=columns)
#alias
#.select(df.emp_id.alias('empid'),df.name.alias('empname')).show()
#df.select(df.name.like('%d')).show()
#df.filter(df.name.like('%Bob%')).show()
'''df.select(df.emp_id.cast('float')).show()
df.printSchema'''

#-------------------------------------------------------

#filter & where

#df.where(df.emp_id >2).show()
#df.where((df.salary > 60000) & (df.salary <= 780000)).select(df.emp_id, df.name, df.salary).show()
